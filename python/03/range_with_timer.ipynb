# %%
#my_range
# taken from Python documentation
class MyRange:
    """Myrange class """
    def __init__(self,*arguments):
        
        if(len(arguments)==3):
            self.start,self.stop,self.step = arguments
            if self.step==0: 
                raise ValueError("third argument must be different from zero")
            if (self.start>self.stop and self.step>0): 
                raise ValueError("start>stop --> step must be less then zero")
        
        elif(len(arguments)==2):
            self.start , self.stop = arguments
            self.step=1
            if(self.start>self.stop): raise ValueError("When two arguments are passed step is assumed to be equal 1, thus first argument must be smaller than the second one")
        
        elif(len(arguments)==1):
            self.stop=arguments[0]
            self.start=0
            self.step=1
        
        else:
            raise SyntaxError("too few or too many arguments (0 or >=4 arguments have been passed)")
        
        self.data = []
        i=self.start
        if(self.step>0):
            while(i<self.stop):
                self.data.append(i)
                i+=self.step
        else:
            while(i>self.stop):
                self.data.append(i)
                i+=self.step
        
        self.index=0


    def __iter__(self):
        self.index=0
        return self
    
    def __next__(self):
        if self.index == len(self.data):
            raise StopIteration
        self.index = self.index + 1
        return self.data[self.index-1]
    
    def __getitem__(self,key):
        return self.data[key]
    
    def __setitem__(self,key,item):
        self.data[key]=item
    
    def __str__(self):
        return 'MyRange:({},{},{})'.format(self.start,self.stop,self.step)

# %%
a=MyRange(6,0,1)
b=range(6,0,-1)
for j in a:
    print(j)
print("let's loop again")
for x in b:
    print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-2bbb083a81d0> in <module>
# ----> 1 a=MyRange(6,0,1)
#       2 b=range(6,0,-1)
#       3 for j in a:
#       4     print(j)
#       5 print("let's loop again")
#
# <ipython-input-5-ae5e7746dece> in __init__(self, *arguments)
#      10                 raise ValueError("third argument must be different from zero")
#      11             if (self.start>self.stop and self.step>0):
# ---> 12                 raise ValueError("start>stop --> step must be less then zero")
#      13
#      14         elif(len(arguments)==2):
#
# ValueError: start>stop --> step must be less then zero

# %%
def myrange(*arguments):
    if(len(arguments)==3):
            start,stop,step = arguments
            if step==0: 
                raise ValueError("third argument must be different from zero")
            if (start>stop and step>0): 
                raise ValueError("start>stop --> step must be less then zero")
    
    elif(len(arguments)==2):
            start , stop = arguments
            step=1
            if(start>stop): raise ValueError("When two arguments are passed step is assumed to be equal 1, thus first argument must be smaller than the second one")
        
    elif(len(arguments)==1):
            stop=arguments[0]
            start=0
            step=1
        
        
    else:
            raise ValueError("too few or too many arguments (0 or >=4 arguments have been passed)")
    index=start
    if(start<stop):
        while(index<stop):
            yield start+index
            index+=step
    else:
        while(index>stop):
            yield index
            index+=step

# %%
A=myrange(10)
type(A)=g
# Out:
# <class 'generator'>

# %%
class Timer:
    def __enter__(self): # no other arguments
        print("__enter__")
        import time
        self.t0=time.time_ns()
    
    def __exit__(self, exc_type, exc_value, traceback):
        import time
        # handling of exception, if any
        print("__exit__")
        t1 = time.time()
        self.t1=time.time_ns()
        print("time spent",(self.t1-self.t0)/1000, "us")
        return True # everything has been managed

# %%
for i in range(100):
    with Timer():
        a=myrange(0,100,1)
# Out:
# __enter__
# __exit__
# time spent 34.0 us
# __enter__
# __exit__
# time spent 11.0 us
# __enter__
# __exit__
# time spent 18.0 us
# __enter__
# __exit__
# time spent 16.0 us
# __enter__
# __exit__
# time spent 16.0 us
# __enter__
# __exit__
# time spent 16.0 us
# __enter__
# __exit__
# time spent 16.0 us
# __enter__
# __exit__
# time spent 16.0 us
# __enter__
# __exit__
# time spent 15.0 us
# __enter__
# __exit__
# time spent 19.0 us
# __enter__
# __exit__
# time spent 17.0 us
# __enter__
# __exit__
# time spent 26.0 us
# __enter__
# __exit__
# time spent 16.0 us
# __enter__
# __exit__
# time spent 15.0 us
# __enter__
# __exit__
# time spent 15.0 us
# __enter__
# __exit__
# time spent 15.0 us
# __enter__
# __exit__
# time spent 18.0 us
# __enter__
# __exit__
# time spent 18.0 us
# __enter__
# __exit__
# time spent 15.0 us
# __enter__
# __exit__
# time spent 219.0 us
# __enter__
# __exit__
# time spent 15.0 us
# __enter__
# __exit__
# time spent 12.0 us
# __enter__
# __exit__
# time spent 12.0 us
# __enter__
# __exit__
# time spent 33.0 us
# __enter__
# __exit__
# time spent 12.0 us
# __enter__
# __exit__
# time spent 24.0 us
# __enter__
# __exit__
# time spent 19.0 us
# __enter__
# __exit__
# time spent 36.0 us
# __enter__
# __exit__
# time spent 14.0 us
# __enter__
# __exit__
# time spent 20.0 us
# __enter__
# __exit__
# time spent 20.0 us
# __enter__
# __exit__
# time spent 41.0 us
# __enter__
# __exit__
# time spent 24.0 us
# __enter__
# __exit__
# time spent 9.0 us
# __enter__
# __exit__
# time spent 29.0 us
# __enter__
# __exit__
# time spent 27.0 us
# __enter__
# __exit__
# time spent 8.0 us
# __enter__
# __exit__
# time spent 7.0 us
# __enter__
# __exit__
# time spent 11.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 11.0 us
# __enter__
# __exit__
# time spent 24.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 9.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 12.0 us
# __enter__
# __exit__
# time spent 11.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 29.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 36.0 us
# __enter__
# __exit__
# time spent 29.0 us
# __enter__
# __exit__
# time spent 11.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 11.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 11.0 us
# __enter__
# __exit__
# time spent 11.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 6.0 us
# __enter__
# __exit__
# time spent 141.0 us
# __enter__
# __exit__
# time spent 9.0 us
# __enter__
# __exit__
# time spent 25.0 us
# __enter__
# __exit__
# time spent 17.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 29.0 us
# __enter__
# __exit__
# time spent 8.0 us
# __enter__
# __exit__
# time spent 35.0 us
# __enter__
# __exit__
# time spent 22.0 us
# __enter__
# __exit__
# time spent 12.0 us
# __enter__
# __exit__
# time spent 11.0 us
# __enter__
# __exit__
# time spent 14.0 us
# __enter__
# __exit__
# time spent 18.0 us
# __enter__
# __exit__
# time spent 13.0 us
# __enter__
# __exit__
# time spent 19.0 us
# __enter__
# __exit__
# time spent 11.0 us
# __enter__
# __exit__
# time spent 11.0 us
# __enter__
# __exit__
# time spent 31.0 us
# __enter__
# __exit__
# time spent 12.0 us
# __enter__
# __exit__
# time spent 29.0 us
# __enter__
# __exit__
# time spent 24.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 11.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 10.0 us
# __enter__
# __exit__
# time spent 13.0 us
